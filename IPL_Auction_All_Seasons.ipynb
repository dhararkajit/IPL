# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import numpy as np

# %%
def make_list(rows):
    list_data = []
    head =[row.find_all('th') for row in rows]
    list_data.append([ele.text.strip() for ele in head[0]])
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        list_data.append([ele for ele in cols if ele !=[]])
    return list_data

# %%
url_auction_2008='https://en.wikipedia.org/wiki/2008_Indian_Premier_League'
auction_2008 = urllib.request.urlopen(url_auction_2008)
auc_html_2008 = BeautifulSoup(auction_2008,'lxml')
auc_rows = auc_html_2008.find('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows.find_all('tr')

# %%
list_auc_2008 = make_list(auc_rows)

# %%
df_auc_2008 = pd.DataFrame(list_auc_2008[2:], columns = list_auc_2008[0])

# %%
df_auc_2008
# Out:
#    Nat                                         Player  \
# 0           Dhoni, Mahendra SinghMahendra Singh Dhoni
# 1                       Gilchrist, AdamAdam Gilchrist
# 2           Muralitharan, MuttiahMuttiah Muralitharan
# 3               Jayawardene, MahelaMahela Jayawardene
# 4                             Warne, ShaneShane Warne
# 5                         Akhtar, ShoaibShoaib Akhtar
# 6                             Kumble, AnilAnil Kumble
# 7                     Singh, HarbhajanHarbhajan Singh
# 8                 Jayasuriya, SanathSanath Jayasuriya
# 9                   Sangakkara, KumarKumar Sangakkara
# 10                        Ponting, RickyRicky Ponting
# 11                                Lee, BrettBrett Lee
# 12                      Symonds, AndrewAndrew Symonds
# 13                      Vettori, DanielDaniel Vettori
# 14                      Hayden, MatthewMatthew Hayden
# 15                  McCullum, BrendonBrendon McCullum
# ...

# %%
url_auction_2009='https://en.wikipedia.org/wiki/List_of_2009_Indian_Premier_League_personnel_changes#Auction'
auction_2009 = urllib.request.urlopen(url_auction_2009)
auc_html_2009 = BeautifulSoup(auction_2009,'lxml')
auc_rows = auc_html_2009.find('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows.find_all('tr')

# %%
list_auc_2009 = make_list(auc_rows)

# %%
df_auc_2009 = pd.DataFrame(list_auc_2009[2:], columns = list_auc_2009[0])

# %%
df_auc_2009
# Out:
#                Nat             Player Team Winning bid  Base price
# 0      Australia !         Shaun Tait         $375,000    $250,000
# 1   South Africa !          JP Duminy         $950,000    $300,000
# 2        England !    Andrew Flintoff       $1,550,000    $950,000
# 3        England !    Kevin Pietersen       $1,550,000  $1,350,000
# 4    West Indies !      Fidel Edwards         $150,000    $150,000
# 5        England !         Owais Shah         $275,000    $150,000
# 6        England !   Paul Collingwood         $275,000    $250,000
# 7   South Africa !    Tyron Henderson         $650,000    $100,000
# 8        England !        Ravi Bopara         $450,000    $150,000
# 9      Sri Lanka !    Thilan Thushara         $140,000    $100,000
# 10   New Zealand !        Jesse Ryder         $160,000    $100,000
# 11   New Zealand !         Kyle Mills         $150,000    $150,000
# 12   West Indies !       Dwayne Smith         $100,000    $100,000
# ...

# %%
url_auction_2010='https://en.wikipedia.org/wiki/List_of_2010_Indian_Premier_League_personnel_changes'
auction_2010 = urllib.request.urlopen(url_auction_2010)
auc_html_2010 = BeautifulSoup(auction_2010,'lxml')
auc_rows = auc_html_2010.find('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows.find_all('tr')

# %%
list_auc_2010 = make_list(auc_rows)

# %%
df_auc_2010 = pd.DataFrame(list_auc_2010[2:], columns = list_auc_2010[0])

# %%
df_auc_2010
# Out:
#                              Player                    Franchise  \
# 0            Bond, ShaneShane Bond†        Kolkata Knight Riders
# 1    Pollard, KieronKieron Pollard†               Mumbai Indians
# 2           Roach, KemarKemar Roach              Deccan Chargers
# 3       Parnell, WayneWayne Parnell             Delhi Daredevils
# 4       Kaif, MohammadMohammad Kaif              Kings XI Punjab
# 5           Morgan, EoinEoin Morgan  Royal Challengers Bangalore
# 6       Martyn, DamienDamien Martyn             Rajasthan Royals
# 7           Kemp, JustinJustin Kemp          Chennai Super Kings
# 8   Perera, ThissaraThissara Perera          Chennai Super Kings
# 9             Voges, AdamAdam Voges             Rajasthan Royals
# 10      Abdulla, YusufYusuf Abdulla              Kings XI Punjab
#
#    Sold price (USD) Base price (USD)
# 0           750,000           100000
# 1           750,000          200,000
# 2           720,000          100,000
# ...

# %%
url_auction_2011='https://en.wikipedia.org/wiki/List_of_2011_Indian_Premier_League_personnel_changes'
auction_2011 = urllib.request.urlopen(url_auction_2011)
auc_html_2011 = BeautifulSoup(auction_2011,'lxml')
auc_rows = auc_html_2011.find('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows.find_all('tr')

# %%
list_auc_2011 = make_list(auc_rows)

# %%
df_auc_2011 = pd.DataFrame(list_auc_2011[2:], columns = list_auc_2011[0])

# %%
df_auc_2011
# Out:
#                 Nat                                       Player  \
# 0           India !                Gambhir, GautamGautam Gambhir
# 1           India !                    Pathan, YusufYusuf Pathan
# 2           India !                  Uthappa, RobinRobin Uthappa
# 3           India !                    Sharma, RohitRohit Sharma
# 4           India !                    Pathan, IrfanIrfan Pathan
# 5           India !                    Singh, YuvrajYuvraj Singh
# 6           India !                Tiwary, SaurabhSaurabh Tiwary
# 7       Sri Lanka !        Jayawardene, MahelaMahela Jayawardene
# 8       Australia !                    Hussey, DavidDavid Hussey
# 9    South Africa !                        Steyn, DaleDale Steyn
# 10      Sri Lanka !    Muralitharan, MuttiahMuttiah Muralitharan
# 11      Australia !                  White, CameronCameron White
# 12   South Africa !                Kallis, JacquesJacques Kallis
# ...

# %%
url_auction_2012='https://en.wikipedia.org/wiki/List_of_2012_Indian_Premier_League_personnel_changes'
auction_2012 = urllib.request.urlopen(url_auction_2012)
auc_html_2012 = BeautifulSoup(auction_2012,'lxml')

# %%
auc_rows = auc_html_2012.find_all('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows[3].find_all('tr')

# %%
list_auc_2012 = make_list(auc_rows)

# %%
df_auc_2012 = pd.DataFrame(list_auc_2012[2:], columns = list_auc_2012[0])

# %%
auc_2012 = df_auc_2012[['Player','Team','Base price','Winning bid']]

# %%
url_auction_2013='https://en.wikipedia.org/wiki/List_of_2013_Indian_Premier_League_personnel_changes'
auction_2013 = urllib.request.urlopen(url_auction_2013)
auc_html_2013 = BeautifulSoup(auction_2013,'lxml')
auc_rows = auc_html_2013.find_all('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows[2].find_all('tr')

# %%
list_auc_2013 = make_list(auc_rows)

# %%
df_auc_2013 = pd.DataFrame(list_auc_2013[2:], columns = list_auc_2013[0])

# %%
auc_2013= df_auc_2013[['Player','Team','Base price','Winning bid']]

# %%
url_auction_2014='https://en.wikipedia.org/wiki/List_of_2014_Indian_Premier_League_personnel_changes'
auction_2014 = urllib.request.urlopen(url_auction_2014)
auc_html_2014 = BeautifulSoup(auction_2014,'lxml')
auc_rows = auc_html_2014.find_all('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows[1].find_all('tr')

# %%
list_auc_2014 = make_list(auc_rows)

# %%
df_auc_2014 = pd.DataFrame(list_auc_2014[2:], columns = list_auc_2014[0])

# %%
auc_2014 = df_auc_2014[['Name','IPL 2014 Team','Reserve Price in Lakhs in INR','Auctioned Price in Lakhs in INR']]

# %%
url_auction_2015='https://en.wikipedia.org/wiki/List_of_2015_Indian_Premier_League_personnel_changes'
auction_2015 = urllib.request.urlopen(url_auction_2015)
auc_html_2015 = BeautifulSoup(auction_2015,'lxml')
auc_rows = auc_html_2015.find_all('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows[1].find_all('tr')

# %%
list_auc_2015 = make_list(auc_rows)

# %%
df_auc_2015 = pd.DataFrame(list_auc_2015[2:], columns = list_auc_2015[0])

# %%
df_auc_2015.columns = ['Name','Nat','IPL Matches','IPL teams','IPL 2014 team','Capped / uncapped','Base Price','IPL 2015 team','Auctioned price']

auc_2015 = df_auc_2015[['Name','IPL 2015 team','Base Price','Auctioned price']]

# %%
url_auction_2016='https://en.wikipedia.org/wiki/List_of_2016_Indian_Premier_League_personnel_changes'
auction_2016 = urllib.request.urlopen(url_auction_2016)
auc_html_2016 = BeautifulSoup(auction_2016,'lxml')
auc_rows = auc_html_2016.find_all('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows[1].find_all('tr')

# %%
list_auc_2016 = make_list(auc_rows)

# %%
df_auc_2016 = pd.DataFrame(list_auc_2016[2:], columns = list_auc_2016[0])

# %%
df_auc_2016.columns = ['Nat','Player','team','Base Price','Winning bid']

auc_2016=df_auc_2016[['Player','team','Base Price','Winning bid']]

# %%
url_auction_2017 ='https://en.wikipedia.org/wiki/List_of_2017_Indian_Premier_League_personnel_changes'
auction_2017 = urllib.request.urlopen(url_auction_2017)
auc_html_2017 = BeautifulSoup(auction_2017,'lxml')
auc_rows = auc_html_2017.find_all('table',attrs={'class':'wikitable sortable'})
auc_rows = auc_rows[0].find_all('tr')

# %%
list_auc_2017 = make_list(auc_rows)

# %%
df_auc_2017 = pd.DataFrame(list_auc_2017[2:], columns = list_auc_2017[0])

# %%
df_auc_2017.columns = ['Nat','Player','team','Base Price','Winning bid']

auc_2017 = df_auc_2017[['Player','team','Base Price','Winning bid']]

# %%
auc_2012
# Out:
#                                        Player                         Team  \
# 0           McCullum, BrendonBrendon McCullum        Kolkata Knight Riders
# 1             Jadeja, RavindraRavindra Jadeja          Chennai Super Kings
# 2   Muralitharan, MuttiahMuttiah Muralitharan  Royal Challengers Bangalore
# 3       Jayawardene, MahelaMahela Jayawardene             Delhi Daredevils
# 4           Gibbs, HerschelleHerschelle Gibbs               Mumbai Indians
# 5                       Hodge, BradBrad Hodge             Rajasthan Royals
# 6                 Patel, ParthivParthiv Patel              Deccan Chargers
# 7           Chandimal, DineshDinesh Chandimal             Rajasthan Royals
# 8                 Russell, AndreAndre Russell             Delhi Daredevils
# 9           Johnson, MitchellMitchell Johnson               Mumbai Indians
# 10                    Singh, R. P.R. P. Singh               Mumbai Indians
# ...

# %%
auc_2013
# Out:
#                                        Player                         Team  \
# 0   Barnwell, ChristopherChristopher Barnwell               Mumbai Indians
# 1                     Botha, JohanJohan Botha             Delhi Daredevils
# 2           Christian, DanielDaniel Christian  Royal Challengers Bangalore
# 3               Clarke, MichaelMichael Clarke          Pune Warriors India
# 4     Coulter-Nile, NathanNathan Coulter-Nile               Mumbai Indians
# 5             Dananjaya, AkilaAkila Dananjaya          Chennai Super Kings
# 6             de Kock, QuintonQuinton de Kock          Sunrisers Hyderabad
# 7                 Edwards, FidelFidel Edwards             Rajasthan Royals
# 8               Faulkner, JamesJames Faulkner             Rajasthan Royals
# 9                 Gony, ManpreetManpreet Gony              Kings XI Punjab
# 10          Henriques, MoisésMoisés Henriques  Royal Challengers Bangalore
# ...

# %%
auc_2014
# Out:
#                       Name                     IPL 2014 Team  \
# 0         Mitchell Johnson                   Kings XI Punjab
# 1           Jacques Kallis             Kolkata Knight Riders
# 2          Kevin Pietersen                  Delhi Daredevils
# 3          Virender Sehwag                   Kings XI Punjab
# 4             Yuvraj Singh       Royal Challengers Bangalore
# 5             Murali Vijay                  Delhi Daredevils
# 6             David Warner               Sunrisers Hyderabad
# 7            George Bailey                   Kings XI Punjab
# 8           Faf du Plessis               Chennai Super Kings
# 9           Michael Hussey                    Mumbai Indians
# 10          Dinesh Karthik                  Delhi Daredevils
# 11             Zaheer Khan                    Mumbai Indians
# 12        Brendon McCullum               Chennai Super Kings
# 13             Amit Mishra               Sunrisers Hyderabad
# ...

# %%
auc_2015
# Out:
#                      Name                IPL 2015 team Base Price  \
# 0          Michael Hussey          Chennai Super Kings        150
# 1            Irfan Pathan          Chennai Super Kings        150
# 2            Rahul Sharma          Chennai Super Kings         30
# 3             Kyle Abbott          Chennai Super Kings         30
# 4              Andrew Tye          Chennai Super Kings         20
# 5          Pratyush Singh          Chennai Super Kings         10
# 6            Ankush Bains          Chennai Super Kings         10
# 7         Eklavya Dwivedi          Chennai Super Kings         10
# 8            Yuvraj Singh             Delhi Daredevils        200
# 9          Angelo Mathews             Delhi Daredevils        150
# 10            Zaheer Khan             Delhi Daredevils        100
# 11            Amit Mishra             Delhi Daredevils         10
# 12           Shreyas Iyer             Delhi Daredevils         10
# ...

# %%
auc_2016
# Out:
#                                  Player                         team  \
# 0       Pietersen, KevinKevin Pietersen       Rising Pune Supergiant
# 1             Smith, DwayneDwayne Smith                Gujarat Lions
# 2           Sharma, IshantIshant Sharma       Rising Pune Supergiant
# 3             Watson, ShaneShane Watson  Royal Challengers Bangalore
# 4             Nehra, AshishAshish Nehra          Sunrisers Hyderabad
# 5             Singh, YuvrajYuvraj Singh          Sunrisers Hyderabad
# 6                 Steyn, DaleDale Steyn                Gujarat Lions
# 7             Samson, SanjuSanju Samson             Delhi Daredevils
# 8               Buttler, JosJos Buttler               Mumbai Indians
# 9         Karthik, DineshDinesh Karthik                Gujarat Lions
# 10            Pathan, IrfanIrfan Pathan       Rising Pune Supergiant
# 11            Morris, ChrisChris Morris             Delhi Daredevils
# 12              Munro, ColinColin Munro        Kolkata Knight Riders
# ...

# %%
auc_2017
# Out:
#                  Player                         team Base Price Winning bid
# 0           Eoin Morgan              Kings XI Punjab        200         200
# 1            Pawan Negi  Royal Challengers Bangalore         30         100
# 2        Angelo Mathews             Delhi Daredevils        200         200
# 3            Ben Stokes      Rising Pune Supergiants        200        1450
# 4        Corey Anderson             Delhi Daredevils        100         100
# 5       Nicholas Pooran               Mumbai Indians         30          30
# 6         Kagiso Rabada             Delhi Daredevils        100         500
# 7           Trent Boult        Kolkata Knight Riders        150         500
# 8           Tymal Mills  Royal Challengers Bangalore         50        1200
# 9           Pat Cummins             Delhi Daredevils        200         450
# 10     Mitchell Johnson               Mumbai Indians        200         200
# ...
